# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df_test = pd.read_csv("Test_Data_Set.csv")

# %%
df_train = pd.read_csv("Training_Data_Set.csv")

# %%
df_train.shape
# Out:
# (53515, 17)

# %%
df_test.shape
# Out:
# (5615, 16)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   53515 non-null  int64
#  1   Maker                53515 non-null  object
#  2   model                53515 non-null  object
#  3   Location             53509 non-null  object
#  4   Distance             52304 non-null  float64
#  5   Owner Type           53515 non-null  object
#  6   manufacture_year     53513 non-null  float64
#  7   Age of car           53515 non-null  int64
#  8   engine_displacement  53515 non-null  int64
#  9   engine_power         52076 non-null  float64
#  10  body_type            4136 non-null   object
#  11  Vroom Audit Rating   53515 non-null  int64
#  12  transmission         53515 non-null  object
#  13  door_count           53515 non-null  object
#  14  seat_count           53515 non-null  object
# ...

# %%
df_train.describe(include="all").T
# Out:
#                        count unique         top   freq            mean  \
# ID                   53515.0    NaN         NaN    NaN      11126758.0
# Maker                  53515      8       skoda  21563             NaN
# model                  53515     23     octavia  12619             NaN
# Location               53509     11  Coimbatore   4974             NaN
# Distance             52304.0    NaN         NaN    NaN    94546.262446
# Owner Type             53515      4       First  13406             NaN
# manufacture_year     53513.0    NaN         NaN    NaN     2010.408032
# Age of car           53515.0    NaN         NaN    NaN         8.59189
# engine_displacement  53515.0    NaN         NaN    NaN     1904.049014
# engine_power         52076.0    NaN         NaN    NaN      100.448345
# body_type               4136      2     compact   4127             NaN
# Vroom Audit Rating   53515.0    NaN         NaN    NaN        5.998374
# ...

# %%
df_train.rename(columns = {'Age of car':'Age_of_car', 'Vroom Audit Rating':'Vroom_Audit_Rating', 'Owner Type':'Owner_Type'}, inplace = True)

# %%
df_train.manufacture_year.value_counts()
# Out:
# 2015.0    12386
# 2012.0     6250
# 2011.0     4939
# 2014.0     4877
# 2010.0     3778
# 2009.0     2914
# 2013.0     2910
# 2008.0     2859
# 2007.0     2840
# 2006.0     2018
# 2005.0     1705
# 2004.0     1341
# 2003.0      945
# 2001.0      751
# 2002.0      743
# 2000.0      727
# 1999.0      540
# 1998.0      313
# 2016.0      205
# 1997.0      141
# 1996.0       75
# 1994.0       37
# 1991.0       32
# 1995.0       31
# 1993.0       22
# 1992.0       21
# 1990.0       17
# 1989.0       13
# 1968.0       13
# 1988.0       10
# 1950.0        6
# 1984.0        6
# 1985.0        5
# 1982.0        4
# 1980.0        4
# 1973.0        4
# 1986.0        4
# 1971.0        3
# 1983.0        3
# 1972.0        2
# 1962.0        2
# 1987.0        2
# 1964.0        2
# 1966.0        2
# 1959.0        1
# 1960.0        1
# 1974.0        1
# 1952.0        1
# 1955.0        1
# 1969.0        1
# 1934.0        1
# 1981.0        1
# 1956.0        1
# 1976.0        1
# 1963.0        1
# ...

# %%
ax = sns.countplot(x="manufacture_year", data=df_train)

# %%
df_train.Age_of_car.value_counts()
# Out:
# 4     12387
# 7      6250
# 8      4939
# 5      4877
# 9      3779
# 10     2914
# 6      2910
# 11     2859
# 12     2840
# 13     2018
# 14     1705
# 15     1341
# 16      945
# 18      751
# 17      743
# 19      727
# 20      540
# 21      313
# 3       205
# 22      141
# 23       75
# 25       37
# 28       32
# 24       31
# 26       22
# 27       21
# 29       17
# 30       13
# 51       13
# 31       10
# 69        6
# 35        6
# 34        5
# 46        4
# 39        4
# 37        4
# 33        4
# 48        3
# 36        3
# 57        2
# 32        2
# 47        2
# 55        2
# 53        2
# 56        1
# 85        1
# 50        1
# 64        1
# 59        1
# 45        1
# 60        1
# 43        1
# 38        1
# 67        1
# 63        1
# Name: Age_of_car, dtype: int64

# %%
ax = sns.countplot(x="Age_of_car", data=df_train)

# %%
df_train.Vroom_Audit_Rating.value_counts()
# Out:
# 8    10823
# 4    10769
# 5    10740
# 6    10638
# 7    10545
# Name: Vroom_Audit_Rating, dtype: int64

# %%
ax = sns.countplot(x="Vroom_Audit_Rating", data=df_train)

# %%
labels = df_train.Vroom_Audit_Rating.value_counts().index
df_train.Vroom_Audit_Rating.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='Vroom_Audit_Rating'>

# %%
df_train.Maker.value_counts()
# Out:
# skoda       21563
# toyota       7840
# audi         7326
# bmw          7178
# nissan       5485
# hyundai      2240
# fiat         1845
# maserati       38
# Name: Maker, dtype: int64

# %%
labels = df_train.Maker.value_counts().index
df_train.Maker.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
plt.legend(  bbox_to_anchor=(-0.1, 1.),fontsize=8)

# %%
ax = sns.countplot(x="Maker", data=df_train)

# %%
df_train.model.value_counts()
# Out:
# octavia     12619
# superb       3195
# yaris        3176
# qashqai      2854
# x3           2779
# x1           2420
# i30          2047
# q5           2039
# x5           1979
# yeti         1898
# panda        1769
# q3           1736
# coupe        1710
# micra        1676
# auris        1666
# avensis      1512
# aygo         1486
# rapid        1409
# roomster     1322
# q7           1245
# citigo       1120
# juke          955
# tt            903
# Name: model, dtype: int64

# %%
ax = sns.countplot(x="model", data=df_train)

# %%
df_train.Location.value_counts()
# Out:
# Coimbatore    4974
# Kochi         4969
# Bangalore     4877
# Jaipur        4870
# Kolkata       4867
# Pune          4862
# Mumbai        4860
# Chennai       4834
# Delhi         4822
# Hyderabad     4804
# Ahmedabad     4770
# Name: Location, dtype: int64

# %%
ax = sns.countplot(x="Location", data=df_train)

# %%
df_train.Owner_Type.value_counts()
# Out:
# First             13406
# Third             13395
# Second            13365
# Fourth & Above    13349
# Name: Owner_Type, dtype: int64

# %%
ax = sns.countplot(x="Owner_Type", data=df_train)

# %%
labels = df_train.Owner_Type.value_counts().index
df_train.Owner_Type.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
plt.legend(  bbox_to_anchor=(-0.1, 1.),fontsize=8)

# %%
df_train.body_type.value_counts()
# Out:
# compact    4127
# van           9
# Name: body_type, dtype: int64

# %%
labels = df_train.body_type.value_counts().index
df_train.body_type.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
plt.legend(  bbox_to_anchor=(-0.1, 1.),fontsize=8)

# %%
ax = sns.countplot(x="body_type", data=df_train)

# %%
df_train.transmission.value_counts()
# Out:
# man     36734
# auto    16781
# Name: transmission, dtype: int64

# %%
ax = sns.countplot(x="transmission", data=df_train)

# %%
labels = df_train.transmission.value_counts().index
df_train.transmission.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
plt.legend(  bbox_to_anchor=(-0.1, 1.),fontsize=8)

# %%
df_train.door_count.value_counts()
# Out:
# 4       33808
# 5        7630
# None     7534
# 2        4348
# 3         185
# 6           8
# 1           2
# Name: door_count, dtype: int64

# %%
ax = sns.countplot(x="door_count", data=df_train)

# %%
labels = df_train.door_count.value_counts().index
df_train.door_count.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
plt.legend(  bbox_to_anchor=(-0.1, 1.),fontsize=8)

# %%
df_train.seat_count.value_counts()
# Out:
# 5       38824
# None     8511
# 4        4467
# 7         852
# 2         725
# 3         109
# 6          23
# 9           2
# 1           1
# 8           1
# Name: seat_count, dtype: int64

# %%
ax = sns.countplot(x="seat_count", data=df_train)

# %%
labels = df_train.seat_count.value_counts().index
df_train.seat_count.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
plt.legend(  bbox_to_anchor=(-0.1, 1.),fontsize=8)

# %%
df_train.fuel_type.value_counts()
# Out:
# diesel    27559
# petrol    25956
# Name: fuel_type, dtype: int64

# %%
ax = sns.countplot(x="fuel_type", data=df_train)

# %%
labels = df_train.fuel_type.value_counts().index
df_train.fuel_type.value_counts().plot(kind='pie', legend = True, labels=labels, autopct='%.1f%%')
plt.legend(  bbox_to_anchor=(-0.1, 1.),fontsize=8)

# %%
### Examine missing values
df_na = df_train.isna().sum()
df_na[df_na.values > 0].sort_values(ascending=False) # Find out all variables that contain missing values
# Out:
# body_type           49379
# engine_power         1439
# Distance             1211
# Location                6
# manufacture_year        2
# dtype: int64

# %%
Q1 = df_train.quantile(0.25)
Q3 = df_train.quantile(0.75)
IQR = Q3 - Q1
UL = Q3 + 1.5*IQR
LL = Q1 - 1.5*IQR

# %%
((df_train > UL) | (df_train < LL)).sum()
# Out:
# <ipython-input-43-a63c5d11a975>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   ((df_train > UL) | (df_train < LL)).sum()
# <ipython-input-43-a63c5d11a975>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   ((df_train > UL) | (df_train < LL)).sum()
# Age_of_car              785
# Distance                548
# ID                        0
# Location                  0
# Maker                     0
# Owner_Type                0
# Price                  1948
# Vroom_Audit_Rating        0
# body_type                 0
# door_count                0
# engine_displacement    5651
# engine_power           1406
# fuel_type                 0
# ...

# %%
def univariateAnalysis_numeric(column,nbins):
    print("Description of " + column)
    print("----------------------------------------------------------------------------")
    print(df_train[column].describe(),end=' ')
    
    
    plt.figure(figsize=(4,4))
    print("Distribution of " + column)
    print("----------------------------------------------------------------------------")
    plt.hist(x=df_train[column])
    plt.show()
    
    plt.figure(figsize=(4,4))
    print("BoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x=df_train[column])

    plt.show()

# %%
df_num2 = df_train.select_dtypes(include = ['float64', 'int64','int8'])
lstnumericcolumns = list(df_num2.columns.values)
len(lstnumericcolumns)
# Out:
# 8

# %%
for x in lstnumericcolumns:
    univariateAnalysis_numeric(x,20)
# Out:
# Description of ID
# ----------------------------------------------------------------------------
# count    5.351500e+04
# mean     1.112676e+07
# std      1.544859e+04
# min      1.110000e+07
# 25%      1.111338e+07
# 50%      1.112676e+07
# 75%      1.114014e+07
# max      1.115352e+07
# Name: ID, dtype: float64 Distribution of ID
# ----------------------------------------------------------------------------
# BoxPlot of ID
# ----------------------------------------------------------------------------
# Description of Distance
# ----------------------------------------------------------------------------
# count    5.230400e+04
# mean     9.454626e+04
# std      2.755617e+05
# min      0.000000e+00
# 25%      1.549000e+04
# 50%      6.552000e+04
# 75%      1.356410e+05
# max      9.899800e+06
# Name: Distance , dtype: float64 Distribution of Distance
# ----------------------------------------------------------------------------
# BoxPlot of Distance
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   53515 non-null  int64
#  1   Maker                53515 non-null  object
#  2   model                53515 non-null  object
#  3   Location             53509 non-null  object
#  4   Distance             52304 non-null  float64
#  5   Owner_Type           53515 non-null  object
#  6   manufacture_year     53513 non-null  float64
#  7   Age_of_car           53515 non-null  int64
#  8   engine_displacement  53515 non-null  int64
#  9   engine_power         52076 non-null  float64
#  10  body_type            4136 non-null   object
#  11  Vroom_Audit_Rating   53515 non-null  int64
#  12  transmission         53515 non-null  object
#  13  door_count           53515 non-null  object
#  14  seat_count           53515 non-null  object
# ...

# %%
df_train.head()
# Out:
#          ID   Maker    model   Location  Distance       Owner_Type  \
# 0  11100001   skoda  octavia  Ahmedabad        NaN          Second
# 1  11100002    fiat    panda  Ahmedabad    27750.0           Third
# 2  11100003     bmw       x1  Hyderabad    46000.0           Third
# 3  11100004  nissan     juke     Mumbai    43949.0           Third
# 4  11100005     bmw       x5     Jaipur    59524.0  Fourth & Above
#
#    manufacture_year  Age_of_car  engine_displacement  engine_power body_type  \
# 0            1964.0          55                 1964         147.0   compact
# 1            2012.0           7                 1242          51.0       NaN
# 2            2014.0           5                 1995         105.0       NaN
# 3            2011.0           8                 1618         140.0       NaN
# 4            2012.0           7                 2993         180.0       NaN
#
#    Vroom_Audit_Rating transmission door_count seat_count fuel_type       Price
# ...

# %%
# Import label encoder
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
 
# Encode labels in column 'species'.
df_train['Maker']= label_encoder.fit_transform(df_train['Maker'])
df_train['model']= label_encoder.fit_transform(df_train['model'])
df_train['Location']= label_encoder.fit_transform(df_train['Location'])
df_train['Owner_Type']= label_encoder.fit_transform(df_train['Owner_Type'])
df_train['body_type']= label_encoder.fit_transform(df_train['body_type'])
df_train['transmission']= label_encoder.fit_transform(df_train['transmission'])
df_train['fuel_type']= label_encoder.fit_transform(df_train['fuel_type'])

# %%
#df_train["door_count"] = df_train["door_count"].astype('int')
#df_train["seat_count"] = df_train["seat_count"].astype('int')
#df_train["Price"] = df_train["Price"].astype('int')
df_train['door_count'] = pd.to_numeric(df_train['door_count'], errors='coerce')
df_train['seat_count'] = pd.to_numeric(df_train['seat_count'], errors='coerce')
df_train['Price'] = pd.to_numeric(df_train['Price'], errors='coerce')

# %%
#sns.heatmap(df_imputed.corr(),annot=True);
#ax = sns.heatmap(df_imputed.corr(), annot=True, fmt="f")


from string import ascii_letters


sns.set_theme(style="white")

# Generate a large random dataset
#rs = np.random.RandomState(33)
#d = pd.DataFrame(data=rs.normal(size=(100, 26)),
#                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = df_train.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
#calculate column correlations and make a seaborn heatmap - Before standardisation
corr = df_train.corr()
kot = corr[corr>=0.4]
plt.figure(figsize=(29,29))
#p.set(font_scale=2)
# setting the size of figure to 12 by 10
#p=sns.heatmap(kot, annot=True,square=True,annot_kws={'size':16})
#sns.color_palette("light:#5A9", as_cmap=True)
sns.set(font_scale=2)
heat_map = sns.heatmap(kot, annot=True)
plt.show()

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=10)

# %%
df_train_imputed = pd.DataFrame(imputer.fit_transform(df_train), columns = df_train.columns)

# %%
df_train_imputed.isnull().sum()
# Out:
# ID                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner_Type             0
# manufacture_year       0
# Age_of_car             0
# engine_displacement    0
# engine_power           0
# body_type              0
# Vroom_Audit_Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df_train_imputed.describe().T
# Out:
#                        count          mean            std         min  \
# ID                   53515.0  1.112676e+07   15448.594165  11100001.0
# Maker                53515.0  4.287078e+00       2.554941         0.0
# model                53515.0  1.123993e+01       6.166907         0.0
# Location             53515.0  5.010558e+00       3.157650         0.0
# Distance             53515.0  9.671339e+04  274427.694162         0.0
# Owner_Type           53515.0  1.499841e+00       1.118771         0.0
# manufacture_year     53515.0  2.010408e+03       4.650488      1934.0
# Age_of_car           53515.0  8.591890e+00       4.650322         3.0
# engine_displacement  53515.0  1.904049e+03    1496.564596        14.0
# engine_power         53515.0  1.003028e+02      44.882105        10.0
# body_type            53515.0  1.845595e+00       0.533673         0.0
# Vroom_Audit_Rating   53515.0  5.998374e+00       1.418336         4.0
# ...

# %%
df_train_imputed.boxplot(figsize=(20,8))
plt.xticks(rotation=90)
plt.show()

# %%
#sns.pairplot(df_imputed)

# %%
df_train_imputed.head()
# Out:
#            ID  Maker  model  Location  Distance   Owner_Type  \
# 0  11100001.0    6.0    8.0       0.0   119306.8         2.0
# 1  11100002.0    2.0    9.0       0.0    27750.0         3.0
# 2  11100003.0    1.0   18.0       5.0    46000.0         3.0
# 3  11100004.0    5.0    6.0       9.0    43949.0         3.0
# 4  11100005.0    1.0   20.0       6.0    59524.0         1.0
#
#    manufacture_year  Age_of_car  engine_displacement  engine_power  body_type  \
# 0            1964.0        55.0               1964.0         147.0        0.0
# 1            2012.0         7.0               1242.0          51.0        2.0
# 2            2014.0         5.0               1995.0         105.0        2.0
# 3            2011.0         8.0               1618.0         140.0        2.0
# 4            2012.0         7.0               2993.0         180.0        2.0
#
#    Vroom_Audit_Rating  transmission  door_count  seat_count  fuel_type  \
# ...

# %%
df_test.head()
# Out:
#          ID  Maker    model    Location  Distance       Owner Type  \
# 0  21100001  skoda  octavia      Mumbai   150000.0           First
# 1  21100002  skoda    rapid  Coimbatore    29376.0           Third
# 2  21100003  skoda  octavia  Coimbatore    30563.0          Second
# 3  21100004   audi       q3       Delhi     8650.0  Fourth & Above
# 4  21100005   audi       tt     Chennai     6400.0           Third
#
#    manufacture_year  Age of car  engine_displacement  engine_power body_type  \
# 0              2007          12                 1595          75.0       NaN
# 1              2014           5                 1598          77.0       NaN
# 2              2014           5                 1968         110.0       NaN
# 3              2015           4                 1968         110.0       NaN
# 4              2015           4                 1984         169.0       NaN
#
#    Vroom Audit Rating transmission door_count seat_count fuel_type
# ...

# %%
### Examine missing values
df_na = df_test.isna().sum()
df_na[df_na.values > 0].sort_values(ascending=False) # Find out all variables that contain missing values
# Out:
# body_type       5193
# engine_power     168
# Distance         128
# dtype: int64

# %%
df_test.columns
# Out:
# Index(['ID', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'body_type', 'Vroom Audit Rating', 'transmission', 'door_count',
#        'seat_count', 'fuel_type'],
#       dtype='object')

# %%
df_test.rename(columns = {'Age of car':'Age_of_car', 'Vroom Audit Rating':'Vroom_Audit_Rating', 'Owner Type':'Owner_Type'}, inplace = True)

# %%
# Import label encoder
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
 
# Encode labels in column 'species'.
df_test['Maker']= label_encoder.fit_transform(df_test['Maker'])
df_test['model']= label_encoder.fit_transform(df_test['model'])
df_test['Location']= label_encoder.fit_transform(df_test['Location'])
df_test['Owner_Type']= label_encoder.fit_transform(df_test['Owner_Type'])
df_test['body_type']= label_encoder.fit_transform(df_test['body_type'])
df_test['transmission']= label_encoder.fit_transform(df_test['transmission'])
df_test['fuel_type']= label_encoder.fit_transform(df_test['fuel_type'])

# %%
df_test['door_count'] = pd.to_numeric(df_test['door_count'], errors='coerce')
df_test['seat_count'] = pd.to_numeric(df_test['seat_count'], errors='coerce')

# %%
df_test_imputed = pd.DataFrame(imputer.fit_transform(df_test), columns = df_test.columns)

# %%
df_test_imputed.isnull().sum()
# Out:
# ID                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner_Type             0
# manufacture_year       0
# Age_of_car             0
# engine_displacement    0
# engine_power           0
# body_type              0
# Vroom_Audit_Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
df_train_imputed.drop('ID', axis=1, inplace=True)
df_test_imputed.drop('ID', axis=1, inplace=True)

# %%
# Copy all the predictor variables into X dataframe
X_train = df_train_imputed.drop('Price', axis=1)

# Copy target into the y dataframe.  
y_train = df_train_imputed['Price']

# %%
X_test = df_test_imputed

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.01110072, 0.25708424, 0.03112239, 0.00833699, 0.06024669,
#        0.00718435, 0.13727862, 0.12809796, 0.02498211, 0.1001012 ,
#        0.0116713 , 0.00742997, 0.17396654, 0.0079926 , 0.01065747,
#        0.02274687])

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200,num = 12)]
max_features = ['auto','sqrt']
max_depth = [int(x) for x in np.linspace(5,30,num = 6)]
min_samples_split = [2,5,10,15,100]
min_samples_leaf  = [1,2,5,10]

# %%
grid = {'n_estimators': n_estimators,
        'max_features': max_features,
        'max_depth': max_depth,
        'min_samples_split': min_samples_split,
       'min_samples_leaf': min_samples_leaf}
print(grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import RandomizedSearchCV

model = RandomForestRegressor() 
hyp = RandomizedSearchCV(estimator = model,
                        param_distributions=grid,
                        n_iter=10,
                       scoring= 'neg_mean_squared_error',
                        cv=5,verbose = 2,
                        random_state = 42,n_jobs = 1) 
hyp.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  27.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  27.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  30.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  27.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  27.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  52.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  46.9s
# ...

# %%
y_pred = hyp.predict(X_test)
y_pred
# Out:
# array([ 427322.60659972, 1048421.33027381, 1488733.80192377, ...,
#         369373.52314781, 1129506.1001    ,  560016.75996933])

# %%
x = y_pred
y = np.sort(x)

plt.title("Line graph")
plt.plot(x, y, color="red")

plt.show()

# %%
plt.hist(y_pred, color = 'green',
        histtype = 'bar', rwidth = 0.8)
plt.show()

# %%
array = y_pred
dataframe = pd.DataFrame(array) 
dataframe.to_csv(r"C:\Users\athisya\Downloads\Great Learning\hackathon\Old Car Price\data1.csv")

# %%
#res["Survived"] = pd.DataFrame(ytest_predict)

res = pd.DataFrame(y_pred)
res.index = df_test['ID'] # its important for comparison
res.columns = ["Price"]
#res["PassengerId"] = df_imputed_test['PassengerId']
res.to_csv("prediction_results.csv")
